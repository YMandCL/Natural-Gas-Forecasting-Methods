# 2014-03-31                     28564.0
# ...                                ...
# 2019-06-14                     29747.0
# 2019-06-17                     28041.0
# 2019-06-18                     27797.0
# 2019-06-19                     28996.0
# 2019-06-20                     30213.0
# 2019-06-21                     31672.0
# 2019-06-24                     30971.0
# 2019-06-25                     30704.0
# 2019-06-26                     31241.0
# 2019-06-27                     29226.0
# 2019-06-28                     29568.0
# 2019-07-01                     29569.0
# 2019-07-02                     29320.0
# 2019-07-03                     29125.0
# 2019-07-05                     30568.0
# 2019-07-08                     30608.0
# 2019-07-09                     30602.0
# 2019-07-10                     30913.0
# 2019-07-11                     29234.0
# 2019-07-12                     29663.0
# 2019-07-15                     29908.0
# 2019-07-16                     28329.0
# 2019-07-17                     29345.0
# 2019-07-18                     30019.0
# 2019-07-19                     26914.0
# 2019-07-22                     28099.0
# 2019-07-23                     28860.0
# 2019-07-24                     29093.0
# 2019-07-25                     29986.0
# 2019-07-26                     29752.0
#
# [1368 rows x 8 columns]

# %%
#Create Data Frame
import pandas as pd
ng = quandl.get("Chris/CME_HH1")

# %%
ng.head()
# Out:
#              Open   High    Low   Last  Change  Settle  Volume  \
# Date
# 2014-02-18  5.450  5.562  5.390  5.551   0.337   5.551  3513.0
# 2014-02-19  5.705  6.258  5.705  6.149   0.598   6.149  6804.0
# 2014-02-20  6.139  6.271  5.996  6.064   0.085   6.064  3387.0
# 2014-02-21  6.207  6.207  5.881  6.135   0.071   6.135  5850.0
# 2014-02-24  6.388  6.417  5.416  5.445   0.690   5.445  8648.0
#
#             Previous Day Open Interest
# Date
# 2014-02-18                     37954.0
# 2014-02-19                     39706.0
# 2014-02-20                     39706.0
# 2014-02-21                     40264.0
# 2014-02-24                     39949.0

# %%
ng.tail()
# Out:
#               Open    High     Low    Last  Change  Settle     Volume  \
# Date
# 2019-07-22 2.28300 2.32000 2.27100 2.31700 0.06100 2.31200 1881.00000
# 2019-07-23 2.31800 2.32600 2.28900 2.29000 0.01200 2.30000 5846.00000
# 2019-07-24 2.28700 2.28900 2.21200 2.22900 0.08000 2.22000 5720.00000
# 2019-07-25 2.22900 2.25800 2.22900 2.24000 0.02400 2.24400 3225.00000
# 2019-07-26 2.22500 2.22500 2.16600 2.17300 0.07500 2.16900 7439.00000
#
#             Previous Day Open Interest
# Date
# 2019-07-22                 28099.00000
# 2019-07-23                 28860.00000
# 2019-07-24                 29093.00000
# 2019-07-25                 29986.00000
# 2019-07-26                 29752.00000

# %%
ng.describe(include='all')
# Out:
#               Open         High          Low         Last       Change  \
# count  1364.000000  1368.000000  1368.000000  1368.000000  1361.000000
# mean      3.023971     3.066985     2.978814     3.022375     0.061894
# std       0.686942     0.696830     0.673657     0.685700     0.067891
# min       1.621000     1.675000     1.613000     1.632000     0.001000
# 25%       2.665000     2.697500     2.632000     2.664000     0.023000
# 50%       2.879000     2.919500     2.833000     2.877000     0.044000
# 75%       3.223500     3.261750     3.167000     3.225500     0.078000
# max       6.388000     6.417000     5.996000     6.149000     0.799000
#
#             Settle        Volume  Previous Day Open Interest
# count  1368.000000   1368.000000                 1368.000000
# mean      3.022722   3020.479532                32776.568713
# std       0.686878   2716.881487                 8486.106093
# min       1.639000      5.000000                15967.000000
# 25%       2.662000   1178.750000                26612.250000
# 50%       2.877500   2217.500000                31233.500000
# 75%       3.222500   3851.750000                38090.000000
# max       6.149000  19012.000000                63556.000000

# %%
#Check Data Types 
ng.dtypes
# Out:
# Open                          float64
# High                          float64
# Low                           float64
# Last                          float64
# Change                        float64
# Settle                        float64
# Volume                        float64
# Previous Day Open Interest    float64
# dtype: object

# %%
#Correlation Table
ng.corr()
# Out:
#                                 Open      High       Low      Last    Change  \
# Open                        1.000000  0.997095  0.996820  0.993485  0.308276
# High                        0.997095  1.000000  0.995573  0.996734  0.338476
# Low                         0.996820  0.995573  1.000000  0.997291  0.274363
# Last                        0.993485  0.996734  0.997291  1.000000  0.302743
# Change                      0.308276  0.338476  0.274363  0.302743  1.000000
# Settle                      0.993620  0.996921  0.997200  0.999745  0.305645
# Volume                      0.046412  0.057784  0.037670  0.047140  0.161788
# Previous Day Open Interest  0.228315  0.230656  0.221872  0.224896  0.138711
#
#                               Settle    Volume  Previous Day Open Interest
# Open                        0.993620  0.046412                    0.228315
# High                        0.996921  0.057784                    0.230656
# Low                         0.997200  0.037670                    0.221872
# Last                        0.999745  0.047140                    0.224896
# Change                      0.305645  0.161788                    0.138711
# Settle                      1.000000  0.047234                    0.224468
# Volume                      0.047234  1.000000                    0.087792
# Previous Day Open Interest  0.224468  0.087792                    1.000000

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Boxplot of Volume
sns.boxplot(x="Volume",data=ng)

# %%
#Export Quandl Data to CSV
ng.to_csv(r'C:\\Users\\Watson\NaturalGas.csv')

# %%
#Time Series Plotting
#from pandas import Series
#from matplotlib import pyplot
series = pd.read_csv('NaturalGas.csv', header=0)
series.plot()
plt.show()

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt

# %%
fig, ax = plt.subplots(figsize=(8,6));

ng['Volume'].plot(ax=ax);

ax.set_title('Natural Gas Futures Volume, 2014-2019');
ax.set_ylabel('Volume');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();

# %%
fig, ax = plt.subplots(figsize=(8,6));

ng['Previous Day Open Interest'].plot(ax=ax);

ax.set_title('Natural Gas Futures Open Interest, 2014-2019');
ax.set_ylabel('Open Interest');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();

# %%
fig, ax = plt.subplots(figsize=(8,6));

ng['Settle'].plot(ax=ax);

ax.set_title('Natural Gas Futures, 2014-2019');
ax.set_ylabel('Settlement');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();

# %%
fig, ax = plt.subplots(figsize=(8,6));

ng['Change'].plot(ax=ax);

ax.set_title('Natural Gas Futures Movement, 2014-2019');
ax.set_ylabel('Change');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();

# %% [markdown]
# ## Examine Trend in the Data

# %%
# Examine annual trend in the volume
fig, ax = plt.subplots(figsize=(8,6));

ng['Volume'].resample('AS').sum().plot(ax=ax)

# ax.set_title('Aggregated annual series: International airline passengers, 1949-1960');
fig.suptitle('Aggregated Annual Series: Natural Gas Futures Contract Volume, 2014-2019');
ax.set_ylabel('Volume');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();
fig.subplots_adjust(top=0.9)

# %%
# Examine annual trend in the Open Interest
fig, ax = plt.subplots(figsize=(8,6));

ng['Previous Day Open Interest'].resample('AS').sum().plot(ax=ax)

fig.suptitle('Aggregated Annual Series: Natural Gas Futures Open Interest, 2014-2019');
ax.set_ylabel('Open Interest');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();
fig.subplots_adjust(top=0.9)

# %%
# Examine annual trend in the Settlement Price
fig, ax = plt.subplots(figsize=(8,6));

ng['Settle'].resample('AS').sum().plot(ax=ax)

fig.suptitle('Aggregated Annual Series: Natural Gas Futures Settlement Price, 2014-2019');
ax.set_ylabel('Settlement');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();
fig.subplots_adjust(top=0.9)

# %%
# Examine annual trend in the price movement
fig, ax = plt.subplots(figsize=(8,6));

ng['Change'].resample('AS').sum().plot(ax=ax)

# ax.set_title('Aggregated annual series: International airline passengers, 1949-1960');
fig.suptitle('Aggregated Annual Series: Natural Gas Futures Price Change, 2014-2019');
ax.set_ylabel('Volume');
ax.set_xlabel('Year');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();
fig.subplots_adjust(top=0.9)

# %%
# Examine seasonal trend in the data
#Create Month Column
ng['Month'] = air.index.strftime('%b')
ng['Year'] = air.index.year

air_piv = air.pivot(index='Year', columns='Month', values='n_pass_thousands')

air = air.drop(['Month', 'Year'], axis=1)

# put the months in order
month_names = pd.date_range(start='2016-01-01', periods=12, freq='MS').strftime('%b')
air_piv = air_piv.reindex(columns=month_names)

# plot it
fig, ax = plt.subplots(figsize=(8, 6))
air_piv.plot(ax=ax, kind='box');

ax.set_xlabel('Month');
ax.set_ylabel('Thousands of passengers');
ax.set_title('Boxplot of seasonal values');
ax.xaxis.set_ticks_position('bottom')
fig.tight_layout();

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import sys
import os

#Set Plotting style
pd.set_option('display.float_format', lambda x: '%.5f' % x) # pandas
np.set_printoptions(precision=5, suppress=True) # numpy

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# seaborn plotting style
sns.set(style='ticks', context='poster')

# %%
start = pd.Timestamp('2014-02-18')
end = pd.Timestamp('2019-07-36')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# pandas\_libs\tslibs\np_datetime.pyx in pandas._libs.tslibs.np_datetime._string_to_dts()
#
# ValueError: Day out of range in datetime string "2019-07-36"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1355     else:
# -> 1356         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1357
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     652
# --> 653         ret = self._build_naive(res, default)
#     654
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1226
# -> 1227         naive = default.replace(**repl)
#    1228
#
# ValueError: day is out of range for month
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-76dea320d92f> in <module>
#       1 start = pd.Timestamp('2014-02-18')
# ----> 2 end = pd.Timestamp('2019-07-36')
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp

# %%
# Select the series from 2015 - 2019
ng_short =  ng.loc['2015':'2019']
ng_short.plot(figsize=(12,8))
plt.legend(bbox_to_anchor=(1.25, 0.5))
plt.title("Last 5 Years of Volume")
sns.despine()

# %%
volume = ng['Volume']

# %%
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(volume, lags=20, ax=ax1)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout();

ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(volume, lags=20, ax=ax2)
ax2.xaxis.set_ticks_position('bottom')
fig.tight_layout();

# %%
# Scatterplot matrix is another way to visualize the autocorrelation
# Its advantage is that it is very intuitive, as scatterplot (i.e. one of the plots in a scatterplot matrix) 
# is used often in practice

lags=9

ncols=3
nrows=int(np.ceil(lags/ncols))

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(4*ncols, 4*nrows))

for ax, lag in zip(axes.flat, np.arange(1,lags+1, 1)):
    lag_str = 't-{}'.format(lag)
    X = (pd.concat([volume, volume.shift(-lag)], axis=1,
                   keys=['y'] + [lag_str]).dropna())

    X.plot(ax=ax, kind='scatter', y='y', x=lag_str);
    corr = X.corr().as_matrix()[0][1]
    ax.set_ylabel('Original')
    ax.set_title('Lag: {} (corr={:.2f})'.format(lag_str, corr));
    ax.set_aspect('equal');
    sns.despine();

fig.tight_layout();
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# C:\Users\Watson\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# 4 Plots at Once

def tsplot(y, lags=None, title='', figsize=(14, 8)):
    '''Examine the patterns of ACF and PACF, along with the time series plot and histogram.
    
    Original source: https://tomaugspurger.github.io/modern-7-timeseries.html
    '''
    fig = plt.figure(figsize=figsize)
    layout = (2, 2)
    ts_ax   = plt.subplot2grid(layout, (0, 0))
    hist_ax = plt.subplot2grid(layout, (0, 1))
    acf_ax  = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))
    
    y.plot(ax=ts_ax)
    ts_ax.set_title(title)
    y.plot(ax=hist_ax, kind='hist', bins=25)
    hist_ax.set_title('Histogram')
    smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
    smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
    [ax.set_xlim(0) for ax in [acf_ax, pacf_ax]]
    sns.despine()
    plt.tight_layout()
    return ts_ax, acf_ax, pacf_ax

# %%
tsplot(volume, title='Natural Gas Volume', lags=36);

# %%
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ng['Settle'], lags=20, ax=ax1)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout();

ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ng['Settle'], lags=20, ax=ax2)
ax2.xaxis.set_ticks_position('bottom')
fig.tight_layout();
